# %% [markdown]
# # Baseball Case study  Project

# %% [markdown]
# ## Problem Statement:
# #### This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents number of the win.
#
# ##### Input Features: Runs, At Bat, Hits, Doubles, Triples, Homeruns, Base on Walls, Strikeout,Stolen Bases, Runs Average, Earned Runs, Earned Runs Average, Shutout,Saves, Complete Games and Errors.
# ##### output: Number of predicted wins

# %% [markdown]
# #### . Importing required libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd .read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset contains 16 features which contains statistics summary of the base ball players and 'W' (Wins) is the target variable which predicts the number of wins.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# #### The columns name in our data are not making much sense so, we will convert these into understandable format. As we have given the full explanation of the features in our project deascription so, I will take the new columns name from there.

# %%
# Rename columns in dataset
df.rename(columns={'W' : 'Wins', 
                   'R' : 'Runs Scored', 
                  'AB' : 'At Bat', 
                   'H' : 'Hits', 
                  '2B' : 'Doubles', 
                  '3B' : 'Triples',
                  'HR' : 'Home Runs', 
                  'BB' : 'Base on Balls', 
                  'SO' : 'Strike Outs', 
                  'SB' : 'Stolen Base',
                  'RA' : 'Runs Average', 
                  'ER' : 'Earned Runs', 
                 'ERA' : 'Earned Run Average', 
                  'CG' : 'Complete Game',
                 'SHO' : 'Shut Outs', 
                  'SV' : 'Saves', 
                   'E' : 'Errors'}, 
          inplace=True)

df.head()
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 0    95          724    5575  1497      300       42        139
# 1    83          696    5467  1349      277       44        156
# 2    81          669    5439  1395      303       29        141
# 3    76          622    5533  1381      260       27        136
# 4    74          689    5605  1515      289       49        151
#
#    Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 0            383          973          104           641          601
# 1            439         1264           70           700          653
# 2            533         1157           86           640          584
# 3            404         1231           68           701          643
# 4            455         1259           83           803          746
#
#    Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 0                3.73              2          8     56      88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs Scored         30 non-null     int64
#  2   At Bat              30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Home Runs           30 non-null     int64
#  7   Base on Balls       30 non-null     int64
#  8   Strike Outs         30 non-null     int64
#  9   Stolen Base         30 non-null     int64
#  10  Runs Average        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Game       30 non-null     int64
#  14  Shut Outs           30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %% [markdown]
# . We can observe that this dataset has only numeric data and no column has categorecal data.
#
# . This dataset falls into Regression Analysis.

# %%
df.describe()
# Out:
#              Wins  Runs Scored       At Bat         Hits     Doubles  \
# count   30.000000    30.000000    30.000000    30.000000   30.000000
# mean    80.966667   688.233333  5516.266667  1403.533333  274.733333
# std     10.453455    58.761754    70.467372    57.140923   18.095405
# min     63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000   718.250000  5570.000000  1451.500000  288.750000
# max    100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home Runs  Base on Balls  Strike Outs  Stolen Base  \
# count  30.000000   30.000000      30.000000     30.00000    30.000000
# mean   31.300000  163.633333     469.100000   1248.20000    83.500000
# std    10.452355   31.823309      57.053725    103.75947    22.815225
# ...

# %% [markdown]
# If  we see the mean and 50% rows for diffrent features we can see that the data is slietly skew for most of the features.
#
# Count is same for each variable.
#
# 75% and max values for Errors,Shutout and Run Scored shows the presence of possible outliers.

# %%
df.isnull().sum()
# Out:
# Wins                  0
# Runs Scored           0
# At Bat                0
# Hits                  0
# Doubles               0
# Triples               0
# Home Runs             0
# Base on Balls         0
# Strike Outs           0
# Stolen Base           0
# Runs Average          0
# Earned Runs           0
# Earned Run Average    0
# Complete Game         0
# Shut Outs             0
# Saves                 0
# Errors                0
# dtype: int64

# %% [markdown]
# Here, we can see that there are no null values in the data.

# %%
# Visualizing the statistics of the columns by using heatmap
plt.figure(figsize=(20,8))
sns.heatmap(df.describe(),linewidths=0.1,fmt='0.1f',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # EDA
# ## Distribution of features

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1 
for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color='r',hist=False,kde_kws={"shade":True})
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
#     From the above graphs, we can see that some features are left skewed and some are right skewed.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(7,4,plotnumber)
        plt.scatter(df[column],df['Wins'], color='b')
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Wins', fontsize=20)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# As we see in plot, Runs Scored, Earned Run Average,Saves and Shut Outs is almost having a linear relationship with the target variable and other variables are having non-linear relationship with target variables.

# %% [markdown]
# # Boxplot of features

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# As shown in box plot,runs Scored,Earned Run Average,Shut Outs,Saves and Errors having outliers in it.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Base on Balls", data=df,palette='PiYG')
plt.show()

# %% [markdown]
# Base on ball is contribution from pitcher to batter for winning. In simple word it is like Wide or No Ball in Cricket.
#
# We can see that base on ball above 400 really contribute in Wins in team.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Scored", data=df,palette='PiYG')
plt.show()

# %% [markdown]
# Runs scored above 600 is benchmark for winning any scenario.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Average", data=df,palette='gist_earth')
plt.title('Bar plot of Wins Vs Run Average', fontsize =20)
plt.show()

# %% [markdown]
# We can see that Run Average decreases with increase in number of wins.
#
# More Run Average gives advantage to the hitter but here wins are high at even low runs. This cleary means that performance of pitcher is better than hitter. This must be reflected in any pitcher side statistical parameter like Strike Out,Earned Run and Earned Run Average.

# %% [markdown]
# # Relation of wins with parameters like ERA and Strike Out

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Earned Run Average", data=df,palette='spring')
plt.xlabel('Wins',fontsize =16)
plt.ylabel('Earned Run Average',fontsize =16)
plt.show()

# %% [markdown]
# From here, we can see that ERA is lowfor maximum wins. Low ERA by pitcher means that pitcher is giving less chance to score run.
#
# We come to conclusion that ERA is less than 3.5
#
# But this also indicate that ERA and Run Average score are bound to related each other in linear relationship( maybe positive or negative).

# %%
# There is one outlier in Runs Score, let's check that entey
df['Runs Scored'].max()
# Out:
# 891

# %%
df.loc[df['Runs Scored']==891]
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 5    93          891    5509  1480      308       17        232
#
#    Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 5            570         1151           88           670          609
#
#    Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 5                 3.8              7         10     34      88

# %% [markdown]
# It looks like highest Doubles, Homeruns and  base balls also belong to this entry

# %%
df['Home Runs'].max(),df['Doubles'].max(),df['Base on Balls'].max()
# Out:
# (232, 308, 570)

# %%
# Joint plot for Earned Run,Earned Run Average and Wins
sns.jointplot(x="Earned Runs", y="Wins", data=df, color="blue",palette="Set1")

# %%
sns.jointplot(x="Earned Run Average", y="Wins", data=df, color="green",palette="Set1")

# %% [markdown]
# Joint plot shows that Earned Runs,Earned Run Average and Wins have negative linear relationship.

# %%
# Relationship between saves and Wins
plt.figure(figsize=(10,10))
sns.jointplot(x="Saves", y="Wins", data=df, color="purple")

# %% [markdown]
# Here we see that increase in number of Saves means increase in number of Wins.

# %%
sns.pairplot(df, hue="Wins")

# %% [markdown]
# # Outliers Detection and Removal

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
print("\033[1m"+'Shape of dataset after removing outliers :'+"\033[0m",df1.shape)
# Out:
# Shape of dataset after removing outliers : (29, 17)

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((30-29)/30)*100,'%')
# Out:
# Percentage Data Loss : 3.3333333333333335 %

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Skewness of features

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game         0.854980
# Shut Outs             0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %% [markdown]
# . Optimal range for skewness is -0.5 to 0.5
#
# . Hits,Complete Game,Shut Outs,Saces and Errors are positively skewed in nature.

# %% [markdown]
# ## Transforming right skew data using boxcox transformation

# %%
from scipy.stats import boxcox

# %%
df1['Hits']=boxcox(df1['Hits'],-2)

# %%
df1['Shut Outs']=boxcox(df1['Shut Outs'],0.5)

# %%
df1['Saves']=boxcox(df1['Saves'],0.5)

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer

# %%
EC=['Errors','Complete Game']
ds =df1[EC].copy()

# %%
column_trans =ColumnTransformer(
    [  ('Errors',PowerTransformer(method='yeo-johnson',standardize=True),['Errors']),
      ('Complete Game',PowerTransformer(method='yeo-johnson',standardize=True),['Complete Game'])])
transformed_yeojohnson =column_trans.fit_transform(df1)   
new_cols=['Errors','Complete Game']
dataset=pd.DataFrame(transformed_yeojohnson,columns=new_cols) #to convert numpy array back into dataframe
pd.concat([dataset],axis=1)
dataset.head()
# Out:
#      Errors  Complete Game
# 0 -0.348265      -0.307098
# 1 -0.540820      -0.307098
# 2 -1.326125       2.011315
# 3  0.650818       1.264463
# 4 -0.540820       1.264463

# %%
# reseting index and mergeing transform data
df1.reset_index(drop=True, inplace=True)
dataset.index=df1.index
df1[EC]=dataset[EC]

# %% [markdown]
# ## Skewness after tranforming features

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.000000
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game        -0.045947
# Shut Outs            -0.085802
# Saves                 0.370280
# Errors                0.065585
# dtype: float64

# %% [markdown]
# ## Correlation

# %%
df1.corr()
# Out:
#                         Wins  Runs Scored    At Bat      Hits   Doubles  \
# Wins                1.000000     0.390451 -0.085780 -0.025885  0.384886
# Runs Scored         0.390451     1.000000  0.438022  0.429083  0.469293
# At Bat             -0.085780     0.438022  1.000000  0.771485  0.490752
# Hits               -0.025885     0.429083  0.771485  1.000000  0.525668
# Doubles             0.384886     0.469293  0.490752  0.525668  1.000000
# Triples            -0.206737     0.134204  0.445604  0.574467  0.342419
# Home Runs           0.245697     0.586894 -0.064653 -0.219890 -0.098695
# Base on Balls       0.447513     0.258450 -0.137850 -0.220426  0.211243
# Strike Outs         0.156469     0.081158 -0.111243 -0.375825 -0.096772
# Stolen Base        -0.169503     0.075323  0.373674  0.424369  0.194308
# Runs Average       -0.823176    -0.013858  0.315499  0.241583 -0.215196
# Earned Runs        -0.815308     0.007727  0.309146  0.278600 -0.224993
# ...

# %%
plt.figure(figsize = (18,6))
df1.corr()['Wins'].drop(['Wins']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Wins',fontsize=15)
plt.title('Correlation of features with Target Variable win',fontsize = 18)
plt.show()

# %% [markdown]
# . At bats,Hits,Complete Game and Errors are very poorly correlated to the target variable.
#
# . Runs Average,Earned Runs,Earned Run Average and Saves are highly correlated with target variable.

# %% [markdown]
# # Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features']= df1.columns
vif
# Out:
#               VIF            Features
# 0     1241.003534                Wins
# 1     3248.685492         Runs Scored
# 2    67999.633336              At Bat
# 3    61783.303243                Hits
# 4     1059.348657             Doubles
# 5       33.888446             Triples
# 6      249.058062           Home Runs
# 7      282.902409       Base on Balls
# 8      414.389674         Strike Outs
# 9       25.992021         Stolen Base
# 10   18626.868530        Runs Average
# 11  153985.893657         Earned Runs
# 12  110924.930008  Earned Run Average
# 13       3.479042       Complete Game
# 14      48.504592           Shut Outs
# 15     840.309823               Saves
# 16       1.885342              Errors

# %% [markdown]
# Earned Run Average,Earned Runs,Runs Average are highly correlated with each other.
#
# At bats and Hits are correlated with each other but, they are very poorly correlated with target variable.
#
# To solve the multicollinearity,we will use the standard scaling method and then PCA.

# %% [markdown]
# # Standard Scaling

# %%
X=df1.drop(columns =['Wins'])
Y=df1['Wins']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(8,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(7))

# %% [markdown]
# ## Checking multicollinearity after applying PCA

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(principle_x.values,i) for i in range(principle_x.shape[1])]
vif['Features']= principle_x.columns
vif
# Out:
#    VIF  Features
# 0  1.0         0
# 1  1.0         1
# 2  1.0         2
# 3  1.0         3
# 4  1.0         4
# 5  1.0         5
# 6  1.0         6

# %% [markdown]
# Now multicollinearity issue is resolved.

# %% [markdown]
# # Machine learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (20, 7)
# Training target vector size: (20,)
# Test feature matrix size: (9, 7)
# Test target vector size: (9,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,250):
    X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=i, test_size=.25)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.9179738330851036 on Random_state 217

# %% [markdown]
# # Linear Regression Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=217, test_size=.25)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [84.58605088 96.26198656 82.50274504 63.77883574 88.03714446 70.54986049
#  82.43803368 72.96772225]
#
#
# Actual Wins:
#  2     81
# 15    98
# 26    79
# 23    63
# 5     87
# 4     74
# 6     81
# 17    68
# Name: Wins, dtype: int64

# %% [markdown]
# # Linear regression Evaluation Matrix

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 2.562335626764824
# Mean squared error : 8.560199512884264
# Root Mean Squared Error: 2.9257818635168724
#
#
#  R2 Score :
# 0.9179738330851036

# %% [markdown]
# ## Cross Validation

# %%
# Cross validation
from sklearn.model_selection import cross_val_score
score= cross_val_score(lin_reg,principle_x,Y,cv=3)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : 0.3354655028709021

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(10):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train,Y_train)  
    y_pred=model.predict(X_test) 
    error = sqrt(mean_squared_error(Y_test,y_pred)) 
    rmse_val.append(error) 
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 8.246211251235321
# RMSE value for k=  2 is: 6.267475568360838
# RMSE value for k=  3 is: 6.1553951042064625
# RMSE value for k=  4 is: 5.050525962709231
# RMSE value for k=  5 is: 5.566866263886713
# RMSE value for k=  6 is: 5.9956581512513445
# RMSE value for k=  7 is: 5.569367750728727
# RMSE value for k=  8 is: 5.896900668995536
# RMSE value for k=  9 is: 6.370868305259728
# RMSE value for k=  10 is: 6.42008566921034

# %%
# Ploting the rmse_val against k values
plt.figure(figsize=(6,4))
plt.plot(range(10),rmse_val,linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)

# %% [markdown]
# At k= 4, we get the minimum RMSE value which approximately 5.050525962709231, and shoots up on further increasing the k value.
# We can safely say that k=4 will give us the best result in this case

# %% [markdown]
# # Other Regression Models

# %%
rf = RandomForestRegressor(n_estimators = 250 ,max_depth=6)
svr=SVR()
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
knn=KNeighborsRegressor()
ls= Lasso()
rd=Ridge()
model = [rf,ls,rd,svr,dtc,adb,gradb,knn]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    
    # Cross Validation
    score = cross_val_score(m, principle_x, Y, cv =4)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('======================================================================================================')
# Out:
#  Error of  RandomForestRegressor(max_depth=6, n_estimators=250) :
# Mean absolute error : 4.567131349206347
# Mean squared error : 33.10241764092338
# Root Mean Squared Error: 5.753470052144477
#
#
#  R2 Score :
# 0.682803603979773
#
#
# Cross Validation Score : RandomForestRegressor(max_depth=6, n_estimators=250) :
#
# Mean CV Score : 0.24764917294082248
# ...
#
#
#  Error of  Lasso() :
# Mean absolute error : 3.3106801008584927
# Mean squared error : 13.20706435528863
# Root Mean Squared Error: 3.6341524947762758
#
#
#  R2 Score :
# 0.8734463065221632
#
#
# Cross Validation Score : Lasso() :
#
# Mean CV Score : 0.6406802173033191
# ...
#
#
#  Error of  Ridge() :
# Mean absolute error : 2.541158609767953
# Mean squared error : 8.510305554715444
# Root Mean Squared Error: 2.9172428000965986
#
#
#  R2 Score :
# 0.918451930603116
#
#
# Cross Validation Score : Ridge() :
#
# Mean CV Score : 0.6758382874990945
# ...
#
#
#  Error of  SVR() :
# Mean absolute error : 7.42331649080171
# ...

# %% [markdown]
#  ### We can see that Ridge Regression gives the maximum R2 score  91.84%. So we will apply hyperparameter tuning on Ridge regression.

# %% [markdown]
# # Final Model

# %%
Final_mod =Ridge(alpha = 0.5, fit_intercept= True,
                                           max_iter = 250, random_state = 32)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 2.5509274926196124
# Mean squared error : 8.521965619133052
# Root Mean Squared Error: 2.9192405894569657
#
#
#  R2 Score of Final Model :
# 0.9183402006850554

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(Final_mod,'Baseballn_Final.csv')
# Out:
# ['Baseballn_Final.csv']
